# %% [markdown]
# <a href="https://colab.research.google.com/github/Asif-PA/PythonPandas/blob/main/Pandas_May_Batch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
a=np.linspace(1,100,10)

# %% [markdown]
# Series is a one-dimensional labeled array capable of holding any data type (integers, strings, floating point numbers, Python objects, etc.). The axis labels are collectively referred to as the index. The basic method to create a Series is to call:

# %% [markdown]
# Pandas Series
# A Series is a one-dimensional array-like object that can hold various types of data, such as integers, floats, strings, and even other Python objects. It is similar to a column in an Excel spreadsheet or a single column in a database table.
#
# Key Characteristics of a Series:
#
# One-Dimensional: It holds a single column of data.
# Indexed: Each element in a Series has an associated index, which can be numeric (default) or a custom index.
# Homogeneous: All elements in a Series are of the same data type.

# %%
b=pd.Series(a)

# %%
b
# Out:
# 0      1.0
# 1     12.0
# 2     23.0
# 3     34.0
# 4     45.0
# 5     56.0
# 6     67.0
# 7     78.0
# 8     89.0
# 9    100.0
# dtype: float64

# %%
b[0:3]
# Out:
# 0     1.0
# 1    12.0
# 2    23.0
# dtype: float64

# %%
b.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
d={"a":0,"b":1,"c":1}

# %%
e=pd.Series(d)

# %%
e
# Out:
# a    0
# b    1
# c    1
# dtype: int64

# %% [markdown]
# # DataFrame

# %% [markdown]
# **DataFrame** is a 2-dimensional labeled data structure with columns of potentially different types. You can think of it like a spreadsheet or SQL table, or a dict of Series objects. It is generally the most commonly used pandas object

# %% [markdown]
# Along with the data, you can optionally pass index (row labels) and columns (column labels) arguments. If you pass an index and / or columns, you are guaranteeing the index and / or columns of the resulting DataFrame. Thus, a dict of Series plus a specific index will discard all data not matching up to the passed index.
#
# If axis labels are not passed, they will be constructed from the input data based on common sense rules.

# %% [markdown]
# # Dictionary of lists

# %% [markdown]
# Dictionary of Lists: Each key represents a column name, and the corresponding list contains the data for that column.

# %%
data={'A':[1,2,3],
      'B':[4,5,6],
      'C':[7,8,9]
    }

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %% [markdown]
# #from Dictionary of series

# %% [markdown]
#  Dictionary of Series: Similar to a dictionary of lists but uses pandas Series instead.

# %%
data={'A':pd.Series([1,2,3]),
      'B':pd.Series([4,5,6])
    }

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %% [markdown]
# Dictionary of Dictionaries: The outer dictionary keys represent the columns, and the inner dictionary keys represent the row indices.

# %%
# Dictionary of dictionaries
data = {
    'A': {0: 1, 1: 2, 2: 3},
    'B': {0: 4, 1: 5, 2: 6},
    'C': {0: 7, 1: 8, 2: 9}
}
df2 = pd.DataFrame(data)
df2
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
arr=np.random.randint(0,100,15)

# %%
arr
# Out:
# array([99, 79, 38, 25, 89, 79, 26, 97, 36, 96, 23,  0, 95, 37, 65])

# %%
df=pd.DataFrame(arr)
df
# Out:
#      0
# 0   99
# 1   79
# 2   38
# 3   25
# 4   89
# 5   79
# 6   26
# 7   97
# 8   36
# 9   96
# 10  23
# 11   0
# 12  95
# 13  37
# 14  65

# %%
arr=np.random.randint(0,100,(5,3))

# %%
arr
# Out:
# array([[51, 57, 29],
#        [84, 77, 38],
#        [67,  9, 45],
#        [29, 42, 99],
#        [35, 61, 96]])

# %%
df=pd.DataFrame(arr)
df
# Out:
#     0   1   2
# 0  51  57  29
# 1  84  77  38
# 2  67   9  45
# 3  29  42  99
# 4  35  61  96

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
rownames=['Mon','Tue','Wed','Thu','Fri']
columnnames=['Jan','Feb','Mar']

# %%
df=pd.DataFrame(arr,index=rownames,columns=columnnames)

# %%
df
# Out:
#      Jan  Feb  Mar
# Mon   51   57   29
# Tue   84   77   38
# Wed   67    9   45
# Thu   29   42   99
# Fri   35   61   96

# %%
path="/content/weather_data.csv"

# %%
df=pd.read_csv(path)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.head(3)
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow

# %%
df.tail(2)
# Out:
#         day  temperature  windspeed  event
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df.shape
# Out:
# (6, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %%
df.columns
# Out:
# Index(['day', 'temperature', 'windspeed', 'event'], dtype='object')

# %%
#renaming a column

# %%
df.rename(columns={'windspeed':'wind-speed'},inplace=True)

# %%
df
# Out:
#         day  temperature  wind-speed  event
# 0  1/1/2017           32           6   Rain
# 1  1/2/2017           35           7  Sunny
# 2  1/3/2017           28           2   Snow
# 3  1/4/2017           24           7   Snow
# 4  1/5/2017           32           4   Rain
# 5  1/6/2017           31           2  Sunny

# %%
df
# Out:
#         day  temperature  wind-speed  event
# 0  1/1/2017           32           6   Rain
# 1  1/2/2017           35           7  Sunny
# 2  1/3/2017           28           2   Snow
# 3  1/4/2017           24           7   Snow
# 4  1/5/2017           32           4   Rain
# 5  1/6/2017           31           2  Sunny

# %%
df.rename(str.upper,axis='columns')
# Out:
#         DAY  TEMPERATURE  WIND-SPEED  EVENT
# 0  1/1/2017           32           6   Rain
# 1  1/2/2017           35           7  Sunny
# 2  1/3/2017           28           2   Snow
# 3  1/4/2017           24           7   Snow
# 4  1/5/2017           32           4   Rain
# 5  1/6/2017           31           2  Sunny

# %%
df
# Out:
#         day  temperature  wind-speed  event
# 0  1/1/2017           32           6   Rain
# 1  1/2/2017           35           7  Sunny
# 2  1/3/2017           28           2   Snow
# 3  1/4/2017           24           7   Snow
# 4  1/5/2017           32           4   Rain
# 5  1/6/2017           31           2  Sunny

# %%
df.rename(lambda x:x.replace("-","_"),axis='columns',inplace=True)

# %%
df
# Out:
#         day  temperature  wind_speed  event
# 0  1/1/2017           32           6   Rain
# 1  1/2/2017           35           7  Sunny
# 2  1/3/2017           28           2   Snow
# 3  1/4/2017           24           7   Snow
# 4  1/5/2017           32           4   Rain
# 5  1/6/2017           31           2  Sunny

# %%
#find the day in which maximum temepraure recorded

# %%
df['day'][df['temperature']==df.temperature.max()]
# Out:
# 1    1/2/2017
# Name: day, dtype: object

# %%
#find the days in which the temperature went above average

# %%
df[['day','temperature','event']][df['temperature']>df.temperature.mean()]
# Out:
#         day  temperature  event
# 0  1/1/2017           32   Rain
# 1  1/2/2017           35  Sunny
# 4  1/5/2017           32   Rain
# 5  1/6/2017           31  Sunny

# %%
df['day']
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df.day
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df['event'].value_counts()
# Out:
# event
# Rain     2
# Sunny    2
# Snow     2
# Name: count, dtype: int64

# %%
df['event'].value_counts(normalize=True)
# Out:
# event
# Rain     0.333333
# Sunny    0.333333
# Snow     0.333333
# Name: proportion, dtype: float64

# %%
df['temperature'].value_counts()
# Out:
# temperature
# 32    2
# 35    1
# 28    1
# 24    1
# 31    1
# Name: count, dtype: int64

# %%
df['event'].unique()
# Out:
# array(['Rain', 'Sunny', 'Snow'], dtype=object)

# %%
df['event'].nunique()
# Out:
# 3

# %%
df['temperature'].max()
# Out:
# 35

# %%
df['temperature'].mean()
# Out:
# 30.333333333333332

# %%
df['temperature'].min()
# Out:
# 24

# %%
df['day']
# Out:
# 0    1/1/2017
# 1    1/2/2017
# 2    1/3/2017
# 3    1/4/2017
# 4    1/5/2017
# 5    1/6/2017
# Name: day, dtype: object

# %%
df[['day','event']]
# Out:
#         day  event
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 2  1/3/2017   Snow
# 3  1/4/2017   Snow
# 4  1/5/2017   Rain
# 5  1/6/2017  Sunny

# %%
df[['day','temperature']]
# Out:
#         day  temperature
# 0  1/1/2017           32
# 1  1/2/2017           35
# 2  1/3/2017           28
# 3  1/4/2017           24
# 4  1/5/2017           32
# 5  1/6/2017           31

# %%
df
# Out:
#         day  temperature  wind_speed  event
# 0  1/1/2017           32           6   Rain
# 1  1/2/2017           35           7  Sunny
# 2  1/3/2017           28           2   Snow
# 3  1/4/2017           24           7   Snow
# 4  1/5/2017           32           4   Rain
# 5  1/6/2017           31           2  Sunny

# %%
df[df['temperature']>30]
# Out:
#         day  temperature  wind_speed  event
# 0  1/1/2017           32           6   Rain
# 1  1/2/2017           35           7  Sunny
# 4  1/5/2017           32           4   Rain
# 5  1/6/2017           31           2  Sunny

# %%
df[['day','event']][df['temperature']>30]
# Out:
#         day  event
# 0  1/1/2017   Rain
# 1  1/2/2017  Sunny
# 4  1/5/2017   Rain
# 5  1/6/2017  Sunny

# %%
df[['day','temperature']][df['temperature']>30]
# Out:
#         day  temperature
# 0  1/1/2017           32
# 1  1/2/2017           35
# 4  1/5/2017           32
# 5  1/6/2017           31

# %%
df
# Out:
#         day  temperature  wind_speed  event
# 0  1/1/2017           32           6   Rain
# 1  1/2/2017           35           7  Sunny
# 2  1/3/2017           28           2   Snow
# 3  1/4/2017           24           7   Snow
# 4  1/5/2017           32           4   Rain
# 5  1/6/2017           31           2  Sunny

# %%
#either temperaure less than 30 or windspeed greater than 5

# %%
df[(df['temperature']<30) |(df['wind_speed']>5)]
# Out:
#         day  temperature  wind_speed  event
# 0  1/1/2017           32           6   Rain
# 1  1/2/2017           35           7  Sunny
# 2  1/3/2017           28           2   Snow
# 3  1/4/2017           24           7   Snow

# %%
#1 temeprure greater than 30 and windspeed less than 5
#or
#2 temeprature less than 30 windspeed greater than 5

# %%
(df['temperature']>30 & df['wind_speed']<5) |
# Out:
#   File "<ipython-input-70-62b4f4963d9a>", line 1
#     (df['temperature']>30 & df['wind_speed']<5) |
#                                                  ^
# SyntaxError: invalid syntax

# %%
df=pd.read_csv("/content/Titanic-Dataset.csv")

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
passengers_survived=df[df['Survived']==1]
passengers_survived
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
passengers_first_class=df[df['Pclass']==1]
passengers_first_class
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
high_fare_passengers=df[(df['Fare']>50)& (df['Pclass']==1)]
high_fare_passengers
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 27            28         0       1
# 31            32         1       1
# ..           ...       ...     ...
# 849          850         1       1
# 856          857         1       1
# 867          868         0       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 27                      Fortune, Mr. Charles Alexander    male  19.0      3
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
young_females=df[(df['Sex']=='female') & (df['Age']<30)]
young_females
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# ..           ...       ...     ...
# 874          875         1       2
# 875          876         1       3
# 880          881         1       2
# 882          883         0       3
# 887          888         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14                Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
young_females.head(5)
# Out:
#     PassengerId  Survived  Pclass  \
# 2             3         1       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# ...

# %% [markdown]
# **Extraction Using Loc Method**
#
# ** Label Based**
#
# ** 2 Arguments ,row,column**

# %%
df

# %%
df.loc[0,'event']

# %%
df.loc[0:3,['event','windspeed']]

# %%
df.loc[[1,3,4],['event','windspeed']]

# %%
df

# %%
df.set_index('day',inplace=True)

# %%
df=df.set_index('day')

# %%
df

# %%
df.loc[['1/1/2017','1/4/2017'],['event','temperature']]

# %%
df.loc['1/1/2017':'1/4/2017',['event','temperature']]

# %%
data = pd.DataFrame({'Brand': ['Maruti', 'Hyundai', 'Tata',
                               'Mahindra', 'Maruti', 'Hyundai',
                               'Renault', 'Tata', 'Maruti'],
                     'Year': [2012, 2014, 2011, 2015, 2012,
                              2016, 2014, 2018, 2019],
                     'Kms Driven': [50000, 30000, 60000,
                                    25000, 10000, 46000,
                                    31000, 15000, 12000],
                     'City': ['Gurgaon', 'Delhi', 'Mumbai',
                              'Delhi', 'Mumbai', 'Delhi',
                              'Mumbai', 'Chennai',  'Ghaziabad'],
                     'Mileage':  [28, 27, 25, 26, 28,
                                  29, 24, 21, 24]})

# %%
df.reset_index(inplace=True)

# %%
data

# %%
#brand maruti and  mileage greater than 25
data.loc[(data['Brand']=='Maruti')& (data['Mileage']>25)]

# %%
data.loc[(data['Brand']=='Maruti')& (data['Mileage']>25),'City']

# %%
data.loc[(data['Brand']=='Maruti')& (data['Mileage']>25),['City','Mileage']]

# %% [markdown]
# # **Iloc**
# **Integer Based**

# %%
df

# %%
df.iloc[0:3,2]

# %%
df

# %%
df.iloc[0,2]

# %%
df.iloc[[1,2,3],[0,1]]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1=pd.read_csv("/content/weather_data.csv")

# %%
df3=df.loc[(df.Sex=='male')&(df.Embarked=='S')]

# %%
df2=df.loc[(df.Sex=='male')&(df.Embarked=='C')]

# %%
df2
# Out:
#      PassengerId  Survived  Pclass                        Name   Sex   Age  \
# 26            27         0       3     Emir, Mr. Farred Chehab  male   NaN
# 30            31         0       1    Uruchurtu, Don. Manuel E  male  40.0
# 34            35         0       1     Meyer, Mr. Edgar Joseph  male  28.0
# 36            37         1       3            Mamee, Mr. Hanna  male   NaN
# 42            43         0       3         Kraeff, Mr. Theodor  male   NaN
# ..           ...       ...     ...                         ...   ...   ...
# 839          840         1       1        Marechal, Mr. Pierre  male   NaN
# 843          844         0       3  Lemberopolous, Mr. Peter L  male  34.5
# 847          848         0       3          Markoff, Mr. Marin  male  35.0
# 859          860         0       3            Razi, Mr. Raihed  male   NaN
# 889          890         1       1       Behr, Mr. Karl Howell  male  26.0
#
#      SibSp  Parch    Ticket     Fare Cabin Embarked
# ...

# %%
df3
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# 12            13         0       3  Saundercock, Mr. William Henry  male
# ..           ...       ...     ...                             ...   ...
# 878          879         0       3              Laleff, Mr. Kristo  male
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df4=pd.concat([df2,df3])

# %%
df4
# Out:
#      PassengerId  Survived  Pclass                           Name   Sex   Age  \
# 26            27         0       3        Emir, Mr. Farred Chehab  male   NaN
# 30            31         0       1       Uruchurtu, Don. Manuel E  male  40.0
# 34            35         0       1        Meyer, Mr. Edgar Joseph  male  28.0
# 36            37         1       3               Mamee, Mr. Hanna  male   NaN
# 42            43         0       3            Kraeff, Mr. Theodor  male   NaN
# ..           ...       ...     ...                            ...   ...   ...
# 878          879         0       3             Laleff, Mr. Kristo  male   NaN
# 881          882         0       3             Markun, Mr. Johann  male  33.0
# 883          884         0       2  Banfield, Mr. Frederick James  male  28.0
# 884          885         0       3         Sutehall, Mr. Henry Jr  male  25.0
# 886          887         0       2          Montvila, Rev. Juozas  male  27.0
#
# ...

# %%
df4=df1.loc[df1['event']=='Sunny']

# %%
df5=df1.loc[df1['event']=='Rain']

# %%
df6=pd.concat([df4,df5])

# %%
df6
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 5  1/6/2017           31          2  Sunny
# 0  1/1/2017           32          6   Rain
# 4  1/5/2017           32          4   Rain

# %%
df7=pd.concat([df4,df5],ignore_index=True)
df7
# Out:
#         day  temperature  windspeed  event
# 0  1/2/2017           35          7  Sunny
# 1  1/6/2017           31          2  Sunny
# 2  1/1/2017           32          6   Rain
# 3  1/5/2017           32          4   Rain

# %% [markdown]
# **Group By & Aggregation**

# %%
df1
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
x=df1.groupby('event')['windspeed'].sum()

# %%
x
# Out:
# event
# Rain     10
# Snow      9
# Sunny     9
# Name: windspeed, dtype: int64

# %%
x=df1.groupby('event')['windspeed'].sum().reset_index()
x
# Out:
#    event  windspeed
# 0   Rain         10
# 1   Snow          9
# 2  Sunny          9

# %%
x=df1.groupby('event')['windspeed'].sum().sort_values().reset_index()
x
# Out:
#    event  windspeed
# 0   Snow          9
# 1  Sunny          9
# 2   Rain         10

# %%
a=df1.groupby('event')['windspeed'].mean().sort_values().reset_index()
a
# Out:
#    event  windspeed
# 0   Snow        4.5
# 1  Sunny        4.5
# 2   Rain        5.0

# %%
y=df1.groupby('event')['windspeed'].agg(['sum','mean']).reset_index()
y
# Out:
#    event  sum  mean
# 0   Rain   10   5.0
# 1   Snow    9   4.5
# 2  Sunny    9   4.5

# %%
df.groupby('Embarked')['Age'].agg(['max','min']).sort_values(by='max',ascending=False)
# Out:
#            max   min
# Embarked
# S         80.0  0.67
# C         71.0  0.42
# Q         70.5  2.00

# %%
df.groupby('Embarked')['Age'].agg(['max','min']).sort_values(by='max',ascending=False)
# Out:
#            max   min
# Embarked
# S         80.0  0.67
# C         71.0  0.42
# Q         70.5  2.00

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
z=df.groupby('Sex').agg({'Fare':'sum','Age':'sum'}).sort_values(by='Fare',ascending=False).reset_index()
z
# Out:
#       Sex        Fare       Age
# 0    male  14727.2865  13919.17
# 1  female  13966.6628   7286.00

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.groupby('Embarked')['Fare'].sum().sort_values(ascending=False).reset_index()
# Out:
#   Embarked        Fare
# 0        S  17439.3988
# 1        C  10072.2962
# 2        Q   1022.2543

# %%
df.groupby('Embarked')['Fare'].sum().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-125-8150e1c75b1c> in <cell line: 1>()
# ----> 1 df.groupby('Embarked')['Fare'].sum().sort_values(by='sum',ascending=False)
#
# TypeError: Series.sort_values() got an unexpected keyword argument 'by'

# %% [markdown]
# **Sorting DataFrame**

# %%
df1
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df1.sort_values(by='temperature',ascending=False)
# Out:
#         day  temperature  windspeed  event
# 1  1/2/2017           35          7  Sunny
# 0  1/1/2017           32          6   Rain
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow

# %%
df1.sort_values(by='temperature')
# Out:
#         day  temperature  windspeed  event
# 3  1/4/2017           24          7   Snow
# 2  1/3/2017           28          2   Snow
# 5  1/6/2017           31          2  Sunny
# 0  1/1/2017           32          6   Rain
# 4  1/5/2017           32          4   Rain
# 1  1/2/2017           35          7  Sunny

# %%
x1=df.loc[(df['Survived']==0)].shape[0]
x1
# Out:
# 549

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Total Fare']=df['SibSp']*df['Fare']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def multiply_5(x):
    return x*5

# %%
df2=df.copy()

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2['Mul']=df2['Fare'].apply(multiply_5)

# %%
#make a function if parameter less than 20 then return Low Fare, between 20 and 100 return Medium fare else high fare

# %%
def ticket_fare(x):
  if x<20:
    return "Low Fare"
  elif x>20 and x<100:
    return "Medium Fare"
  else:
    return "High Fare"

# %%
df2['Ticket Category']=df2['Fare'].apply(ticket_fare)

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  Total Fare          Mul
# count  891.000000  891.000000  891.000000   891.000000
# mean     0.381594   32.204208   25.581969   161.021040
# std      0.806057   49.693429   79.486209   248.467143
# min      0.000000    0.000000    0.000000     0.000000
# 25%      0.000000    7.910400    0.000000    39.552000
# ...

# %%
df2['Encoded Sex']=df2['Sex'].map({'male':1,'female':0})

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017           32          6   Rain
# 1  1/2/2017           35          7  Sunny
# 2  1/3/2017           28          2   Snow
# 3  1/4/2017           24          7   Snow
# 4  1/5/2017           32          4   Rain
# 5  1/6/2017           31          2  Sunny

# %%
df4=df1.copy()

# %%
df4['day']=pd.to_datetime(df4['day'])

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      datetime64[ns]
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 320.0+ bytes

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          6 non-null      object
#  1   temperature  6 non-null      int64
#  2   windspeed    6 non-null      int64
#  3   event        6 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 320.0+ bytes

# %%
df4['Day Name']=df4['day'].dt.day_name()

# %%
df4
# Out:
#          day  temperature  windspeed  event   Day Name
# 0 2017-01-01           32          6   Rain     Sunday
# 1 2017-01-02           35          7  Sunny     Monday
# 2 2017-01-03           28          2   Snow    Tuesday
# 3 2017-01-04           24          7   Snow  Wednesday
# 4 2017-01-05           32          4   Rain   Thursday
# 5 2017-01-06           31          2  Sunny     Friday

# %%
df1['day'].dt.day_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-150-9d8089ffe335> in <cell line: 1>()
# ----> 1 df1['day'].dt.day_name
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#    5990
#    5991     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     222             # we're accessing the attribute of the class, i.e., Dataset.geo
#     223             return self._accessor
# --> 224         accessor_obj = self._accessor(obj)
#     225         # Replace the property with the accessor object. Inspired by:
#     226         # https://www.pydanny.com/cached-property.html
#
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Titanic-Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
def extract_last_name(x):
  y=x.split(',')
  return y[0]

# %%
df['Last Name']=df['Name'].apply(extract_last_name)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
